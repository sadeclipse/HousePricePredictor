# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 0         7912     1.5           0     0          3        1340
# 1         9050     2.0           0     4          5        3370
# 2        11947     1.0           0     0          4        1930
# 3         8030     1.0           0     0          4        1000
# 4        10500     1.0           0     0          4        1140
# ...        ...     ...         ...   ...        ...         ...
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated                    street  \
# 0                 0      1955          2005      18810 Densmore Ave N
# 1               280      1921             0           709 W Blaine St
# 2                 0      1966             0  26206-26214 143rd Ave SE
# 3              1000      1963             0           857 170th Pl NE
# 4               800      1976          1992         9105 170th Ave NE
# ...             ...       ...           ...                       ...
# 4595              0      1954          1979            501 N 143rd St
# 4596              0      1983          2009          14855 SE 10th Pl
# 4597              0      2009             0          759 Ilwaco Pl NE
# 4598           1020      1974             0         5148 S Creston St
# 4599              0      1990             0         18717 SE 258th St
#
#            city  statezip country
# 0     Shoreline  WA 98133     USA
# 1       Seattle  WA 98119     USA
# 2          Kent  WA 98042     USA
# 3      Bellevue  WA 98008     USA
# 4       Redmond  WA 98052     USA
# ...         ...       ...     ...
# 4595    Seattle  WA 98133     USA
# 4596   Bellevue  WA 98007     USA
# 4597     Renton  WA 98059     USA
# 4598    Seattle  WA 98178     USA
# 4599  Covington  WA 98042     USA
#
# [4600 rows x 18 columns]

# %%
df = df.drop(4398)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4599 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4599 non-null   object
#  1   price          4599 non-null   float64
#  2   bedrooms       4599 non-null   float64
#  3   bathrooms      4599 non-null   float64
#  4   sqft_living    4599 non-null   int64
#  5   sqft_lot       4599 non-null   int64
#  6   floors         4599 non-null   float64
#  7   waterfront     4599 non-null   int64
#  8   view           4599 non-null   int64
#  9   condition      4599 non-null   int64
#  10  sqft_above     4599 non-null   int64
#  11  sqft_basement  4599 non-null   int64
#  12  yr_built       4599 non-null   int64
#  13  yr_renovated   4599 non-null   int64
#  14  street         4599 non-null   object
#  15  city           4599 non-null   object
#  16  statezip       4599 non-null   object
#  17  country        4599 non-null   object
# dtypes: float64(4), int64(9), object(5)
# memory usage: 682.7+ KB

# %%
df = df.drop(columns=['country'])
sorted_prices = df.price.sort_values()
idx = sorted_prices[-10:].index.values
df.loc[idx]
# Out:
#                      date       price  bedrooms  bathrooms  sqft_living  \
# 2772  2014-06-18 00:00:00   3000000.0       4.0       4.25         4850
# 1567  2014-05-29 00:00:00   3100000.0       6.0       4.25         6980
# 252   2014-05-07 00:00:00   3200000.0       7.0       4.50         6210
# 1637  2014-05-30 00:00:00   3710000.0       4.0       3.50         5550
# 3729  2014-07-01 00:00:00   3800000.0       5.0       5.50         7050
# 2761  2014-06-18 00:00:00   4489000.0       4.0       3.00         6430
# 2654  2014-06-17 00:00:00   4668000.0       5.0       6.75         9640
# 2286  2014-06-11 00:00:00   7062500.0       5.0       4.50        10040
# 4346  2014-06-23 00:00:00  12899000.0       3.0       2.50         2190
# 4350  2014-07-03 00:00:00  26590000.0       3.0       2.00         1180
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 2772     12445     2.0           1     4          5        3850
# 1567     15682     3.0           0     4          4        5330
# 252       8856     2.5           0     2          5        4760
# 1637     28078     2.0           0     2          4        3350
# 3729     42840     1.0           0     2          4        4320
# 2761     27517     2.0           0     0          3        6430
# 2654     13068     1.0           1     4          3        4820
# 2286     37325     2.0           1     2          3        7680
# 4346     11394     1.0           0     0          3        1550
# 4350      7793     1.0           0     0          4        1180
#
#       sqft_basement  yr_built  yr_renovated                       street  \
# 2772           1000      1989             0  11031 Champagne Point Rd NE
# 1567           1650      1999             0           5243 Forest Ave SE
# 252            1450      1910             0            1230 Warren Ave N
# 1637           2200      2000             0              3222 78th Pl NE
# 3729           2730      1978          2000             1365 91st Ave NE
# 2761              0      2001             0        1149-1199 91st Ave NE
# 2654           4820      1983          2009          5044 Butterworth Rd
# 2286           2360      1940          2001             4442 95th Ave NE
# 4346            640      1956          2001              5426 40th Ave W
# 4350              0      1992             0            12005 SE 219th Ct
#
#                city  statezip
# 2772       Kirkland  WA 98034
# 1567  Mercer Island  WA 98040
# 252         Seattle  WA 98109
# 1637         Medina  WA 98039
# 3729     Clyde Hill  WA 98004
# 2761       Bellevue  WA 98004
# 2654  Mercer Island  WA 98040
# 2286       Bellevue  WA 98004
# 4346        Seattle  WA 98199
# 4350           Kent  WA 98031

# %%
sns.boxplot(data=df, y='price')
# Out:
# <Axes: ylabel='price'>

# %% [markdown]
# As we can see the 'price' field got a lot of variation in it's data, so i will use quantile to account for less outliers to improve overall stability of predictions, since some of the most pricy houses are either a mistaken data or just straight up outliers that cannot be predicted with given data.

# %%
df = df[df['price'].between(*df['price'].quantile([0.012, 0.999]).to_list())]
df.price.describe()
# Out:
# count    4.538000e+03
# mean     5.470729e+05
# std      3.450048e+05
# min      9.000000e+04
# 25%      3.270000e+05
# 50%      4.650000e+05
# 75%      6.574000e+05
# max      3.800000e+06
# Name: price, dtype: float64

# %%
sns.boxenplot(data=df, y='price')
# Out:
# <Axes: ylabel='price'>

# %%
sns.kdeplot(data=df, x='price', fill=True)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %% [markdown]
# Now the data is much less spread so its gonna be easier for us to predict futture values.

# %%
cat_features = ['street', 'city', 'statezip']
for feat in cat_features:
    print(df[feat].nunique())
# Out:
# 4464
# 44
# 77

# %% [markdown]
# I decided to drop these columns since they give me too much varience and they won't give as many information as others columns

# %%
df = df.drop(columns=['street', 'date'])

# %% [markdown]
# ### Here starts ML

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn import svm
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.metrics import root_mean_squared_error, r2_score, mean_absolute_error, mean_absolute_percentage_error

# %%
numerical_cols = df.columns[1:-2]
categorial_cols = df.columns[-2:]
features = df.iloc[:,1:]
target = df.iloc[:, 0]

# %%
train_X, test_X, train_y, test_y = train_test_split(features, target, test_size=0.2)

# %% [markdown]
# #### Creating pipeline

# %% [markdown]
# I decided to create a pipeline to preprocess the data and for future comparisons within models

# %%
numerical_pipe = Pipeline(steps=[
    ('simple_imputer', SimpleImputer(strategy='mean')),
    ('scaler', RobustScaler())
])

categorial_pipe = Pipeline(steps=[
    ('string_imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(handle_unknown='ignore'))
])

preprocessor = ColumnTransformer([
    ('numerical', numerical_pipe, numerical_cols),
    ('categorial', categorial_pipe, categorial_cols),
])

# %%
def create_pipeline(algo):
    return Pipeline([
        ('preprocessing_data', preprocessor),
        ('model', algo)    
    ])

# %% [markdown]
# The next cell will create and fit models so i can compare them using metrics such as rmse, mae, mape, r2_score

# %%
models = []
rmse_scores = []
r2_scores = []
mae = []
mape = []
mpe = []
algorithms = [LinearRegression(),Ridge(),Lasso(), svm.SVR(), RandomForestRegressor(), GradientBoostingRegressor(), AdaBoostRegressor(), XGBRegressor()]

for algo in algorithms:
    pipeline = create_pipeline(algo=algo)

    target_scaler = RobustScaler()
    train_y_scaled = target_scaler.fit_transform(train_y.values.reshape(-1, 1)).ravel()


    pipeline.fit(X=train_X, y=train_y_scaled)
    predictions = pipeline.predict(X=test_X)
    prescaled_pred = target_scaler.inverse_transform(predictions.reshape(-1, 1)).ravel()
    
    models.append(algo.__class__.__name__)
    mae.append(mean_absolute_error(y_true=test_y, y_pred=prescaled_pred))
    rmse_scores.append(root_mean_squared_error(y_true=test_y, y_pred=prescaled_pred))
    r2_scores.append(r2_score(y_true=test_y, y_pred=prescaled_pred))
    mape.append(mean_absolute_percentage_error(y_true=test_y, y_pred=prescaled_pred))

    pe = np.abs((test_y - prescaled_pred) / test_y)
    median_pe = np.median(pe)
    mpe.append(median_pe)
    
    if(isinstance(algo , svm.SVR)):
        plt.scatter(test_y, pe, alpha=0.5)
        plt.show()
        testing_df = pd.DataFrame({'true_price' : test_y, 'pred_price': prescaled_pred})

# %%
testing_df['error'] = testing_df['pred_price']/testing_df['true_price']
testing_df.sort_values(by='error', ascending=False)
# Out:
#       true_price    pred_price     error
# 4349    188000.0  8.304264e+05  4.417162
# 529     110000.0  4.320206e+05  3.927460
# 4432    452500.0  1.623925e+06  3.588785
# 588      90000.0  2.917192e+05  3.241324
# 4529    542500.0  1.515326e+06  2.793228
# ...          ...           ...       ...
# 3863   2271150.0  1.117988e+06  0.492256
# 3089    346000.0  1.646475e+05  0.475860
# 564    1895000.0  8.855329e+05  0.467300
# 1848   1901000.0  8.879524e+05  0.467098
# 4348   2199900.0  1.904058e+05  0.086552
#
# [908 rows x 3 columns]

# %%
pd.DataFrame({
    'Model_names' : models, 
    'RMSE_scores': rmse_scores, 
    'R2_scores': r2_scores, 
    'MAE_scores' : mae, 
    'MAPE_scores': mape, 
    'MPE' : mpe})
# Out:
#                  Model_names    RMSE_scores  R2_scores     MAE_scores  \
# 0           LinearRegression  187099.809171   0.701485  103888.677769
# 1                      Ridge  185764.721557   0.705730  103422.056312
# 2                      Lasso  342445.388590  -0.000004  238896.440342
# 3                        SVR  181752.978398   0.718303   94071.987953
# 4      RandomForestRegressor  190904.049583   0.689222  102461.489024
# 5  GradientBoostingRegressor  183958.651838   0.711424  108237.993269
# 6          AdaBoostRegressor  398010.205782  -0.350852  349358.037062
# 7               XGBRegressor  178871.382359   0.727164   93978.824459
#
#    MAPE_scores       MPE
# 0     0.215048  0.147530
# 1     0.213512  0.145956
# 2     0.555023  0.376884
# 3     0.171731  0.114250
# 4     0.201049  0.116962
# 5     0.226646  0.150289
# 6     0.954877  0.697954
# 7     0.184113  0.118382

# %% [markdown]
# Table above shows, that Linear regression, Ridge, SVR (support vector regression) and XGBRegressor give us best results. Their MPE are 11-15% which shows, that on average error of the model is in this range. This is pretty good considering price of the house can variate from 90k  to 3800k.

# %%
models_log = []
rmse_log = []
r2_log = []
mae_log = []
mape_log = []
mpe_log = []


for algo in algorithms:
    pipeline = create_pipeline(algo=algo)
    train_y_log = np.log1p(train_y)
    pipeline.fit(X=train_X, y=train_y_log)
    
    predictions_log = pipeline.predict(X=test_X)
    final_pred = np.expm1(predictions_log)
    
    models_log.append(algo.__class__.__name__ + "_Log")
    mae_log.append(mean_absolute_error(y_true=test_y, y_pred=final_pred))
    rmse_log.append(root_mean_squared_error(y_true=test_y, y_pred=final_pred))
    r2_log.append(r2_score(y_true=test_y, y_pred=final_pred))
    mape_log.append(mean_absolute_percentage_error(y_true=test_y, y_pred=final_pred))

    pe = np.abs((test_y - final_pred) / test_y)
    mpe_log.append(np.median(pe))

log_results = pd.DataFrame({
    'Model': models_log,
    'RMSE': rmse_log,
    'R2': r2_log,
    'MAE': mae_log,
    'MAPE': mape_log,
    'MedianPE': mpe_log
})

log_results.sort_values(by='MAPE', ascending=True)
# Out:
#                            Model           RMSE        R2            MAE  \
# 3                        SVR_Log  175139.623177  0.738430   90381.809779
# 7               XGBRegressor_Log  176981.401477  0.732900   92331.861080
# 1                      Ridge_Log  178003.397002  0.729806   90605.596602
# 0           LinearRegression_Log  179086.084492  0.726509   90740.641582
# 4      RandomForestRegressor_Log  187229.229259  0.701072  102129.045903
# 5  GradientBoostingRegressor_Log  190432.186948  0.690757  105269.942885
# 6          AdaBoostRegressor_Log  247792.338123  0.476406  158429.411049
# 2                      Lasso_Log  350589.099034 -0.048132  229280.204778
#
#        MAPE  MedianPE
# 3  0.164836  0.108323
# 7  0.169670  0.118656
# 1  0.171388  0.111568
# 0  0.172303  0.111956
# 4  0.188320  0.124476
# 5  0.198730  0.137904
# 6  0.307293  0.244619
# 2  0.462597  0.369780

# %% [markdown]
# As we can see SVR still gives us best results, even after we perform log scale on our data. Lets try to further improve it!

# %%
from sklearn.compose import TransformedTargetRegressor
from sklearn.model_selection import GridSearchCV


model_with_log = TransformedTargetRegressor(
    regressor=create_pipeline(algo=svm.SVR()),
    func=np.log1p,
    inverse_func=np.expm1
)
param_grid = {
    'regressor__model__C': [1, 10, 50],
    'regressor__model__epsilon': [0.005, 0.01, 0.05], # Расширили сетку, так как 0.01 был на краю
    'regressor__model__gamma': ['auto', 'scale'],
    'regressor__model__kernel': ['rbf']
}

grid = GridSearchCV(
    model_with_log, 
    param_grid=param_grid, 
    cv=3, 
    scoring='neg_mean_absolute_error', 
    verbose=2, 
    n_jobs=-1
)

grid.fit(train_X, train_y)

final_pred = grid.predict(test_X)

best_svr = grid.best_estimator_.regressor_.named_steps['model']

final_mape = np.mean(np.abs((test_y - final_pred) / test_y))
print(f"Итоговый MAPE: {final_mape:.4f}")
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# Итоговый MAPE: 0.1572

# %% [markdown]
# This way we imroved our MAPE from 0.164836 to 0.1572 (values will differ cause i didn't put the random state arg in a train_test_split)

# %% [markdown]
# So in the end we got a SVM regressor that predicts prices of the houses with mean absolute percentage error close to 15%!!
# MAE is less then 90k so i think its a pretty decent model overall!
